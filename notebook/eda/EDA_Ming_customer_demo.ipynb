# %% [markdown]
# ### loads the data file

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
# Text Preprocessing
import nltk
# nltk.download("all")
from nltk.corpus import stopwords
import string
from nltk.tokenize import word_tokenize

pd.set_option('display.max_colwidth',10000)
path = 'D:/IC/AIB/P1/subscriptionsdataFINAL.textile'
df = pd.read_csv(path)

# %% [markdown]
# ## cleanse subscription data and add attributes.

# %%
import datetime
#Calculate age
df['Age'] = 2019-df['BirthYear']
#check membership status
#fill null end date as today
df['Status'] = [(1 if str(date) == 'nan' else 0) for date in df['End Date']]
df['End Date'] = [('Aug-19' if str(date) == 'nan' else date) for date in df['End Date']]

# %%
#Cleanse join date and end date
dic_month = {'Jan': "1", 'Feb': "2",'Mar': "3", 'Apr': "4",'May': "5", 'Jun': "6",'Jul': "7", 'Aug': "8",'Sep': "9", 'Oct': "10",'Nov': "11", 'Dec': "12"}
df['Join Month']=df['Join Date'].str.split('-').str[0]
df = df.replace({'Join Month':dic_month})
df['Join Year']= '20'+df['Join Date'].str.split('-').str[1]
df['Join_new']=df['Join Month']+'/'+df['Join Year']

df['End Month']=df['End Date'].str.split('-').str[0]
df = df.replace({'End Month':dic_month})
df['End Year']= '20'+df['End Date'].str.split('-').str[1]
df['End_new']=df['End Month']+'/'+df['End Year']

# %%
import datetime as dt
#Calculate the membership duration
df['Join_new1'] = pd.to_datetime(df['Join_new'],format = '%m/%Y')
df['End_new1'] = pd.to_datetime(df['End_new'],format = '%m/%Y')
df['End Date'] = [('Aug-19' if str(date) == 'nan' else date) for date in df['End Date']]
df['period'] = df['End_new1'] - df['Join_new1']
df['period'] = df['period'].apply(lambda x:x.days)

# %%
# duration
plt.figure(figsize=(20,10))
df['period'].value_counts().plot.bar()
plt.show()
df['period'].describe()
# Out:
# count    850033.000000
# mean        134.942423
# std         109.110657
# min           0.000000
# 25%          61.000000
# 50%          92.000000
# 75%         182.000000
# max        1553.000000
# Name: period, dtype: float64

# %% [markdown]
# ## 75% customer's membership are within 6months.

# %%
# cut membership in bins
df['period group']=pd.cut(x=df['period'], bins=[-float("inf"),30,92,182,365,float("inf")],labels=['<=1months', '1-3months','3-6months', '6-12months','>1year'])

df['period group'].value_counts().plot.bar()
plt.show()
#df.info()
df['period group'].value_counts().sum()
# Out:
# 850033

# %%
df['Club'].unique()
# Out:
# array(['Enfield', 'Greenwich', 'Islington', 'Hounslow', 'Barnet',
#        'Harrow', 'Brent', 'Wandsworth', 'Haringey', 'Waltham Forest',
#        'Ealing', 'Lambeth', 'Tower Hamlets', 'Hackney', 'Southwark',
#        'Camden', 'Sutton', 'Richmond upon Thames', 'Kingston upon Thames',
#        'Bromley', 'Hammersmith', 'Barking', 'Westminster', 'Croydon',
#        'Havering', 'Lewisham', 'Merton', 'Kensington and Chelsea',
#        'Hillingdon', 'Newham', 'Redbridge', 'Bexley'], dtype=object)

# %%
#replace Affluence with indicators
dic_aff = {'A': "0.96", 'B': "0.73",'C1': "0.45", 'C2': "0.25",'DE': "0.1"}
df = df.replace({'Affluence':dic_aff})

# %%
#replace Gender with indicators, 0 as Male and 1 as Female
dic_gen = {'Male': "0", 'Female': "1"}
df = df.replace({'Gender':dic_gen})

# %%
#replace Subscription Type with indicators, 0 as Standard and 1 as Felexible
dic_sub = {'Standard': "0", 'Flexible': "1"}
df = df.replace({'Subscription Type':dic_sub})

# %%
# Age 
df['Age'].value_counts().plot.bar()
plt.show()
df['Age'].describe()
# Out:
# count    850033.000000
# mean         35.230905
# std           7.966825
# min          19.000000
# 25%          29.000000
# 50%          35.000000
# 75%          41.000000
# max          70.000000
# Name: Age, dtype: float64

# %% [markdown]
# ## 75% customer are below 40years old.

# %%
#cut ages into bins
df['Age group']=pd.cut(x=df['Age'], bins=[-float("inf"),19, 29, 39, 49,float("inf")],labels=['<20','20s', '30s', '40s','>40s'])
df['Age group'].value_counts().plot.bar()
plt.show()
df['Age group'].value_counts().sum()
# Out:
# 850033

# %%
df.head()
# Out:
#         Club Join Date Affluence Gender Subscription Type End Date  \
# 0    Enfield    Dec-11      0.45      0                 0   Dec-11
# 1  Greenwich    Jun-18      0.96      1                 0   Aug-19
# 2  Islington    Mar-18      0.73      1                 0   Oct-18
# 3   Hounslow    Oct-15      0.45      1                 0   Dec-15
# 4     Barnet    May-15      0.25      0                 0   Dec-15
#
#    CustomerID  BirthYear  Age  Status  ... Join Year Join_new End Month  \
# 0           1       1992   27       0  ...      2011  12/2011        12
# 1           2       1972   47       1  ...      2018   6/2018         8
# 2           3       1985   34       0  ...      2018   3/2018        10
# 3           4       1972   47       0  ...      2015  10/2015        12
# 4           5       1982   37       0  ...      2015   5/2015        12
#
#   End Year  End_new  Join_new1   End_new1 period  period group Age group
# 0     2011  12/2011 2011-12-01 2011-12-01      0     <=1months       20s
# 1     2019   8/2019 2018-06-01 2019-08-01    426        >1year       40s
# 2     2018  10/2018 2018-03-01 2018-10-01    214    6-12months       30s
# 3     2015  12/2015 2015-10-01 2015-12-01     61     1-3months       40s
# 4     2015  12/2015 2015-05-01 2015-12-01    214    6-12months       30s
#
# [5 rows x 21 columns]

# %%
#drop the redundant columns
drop_columns = ['Join Date', 'End Date', 'Join Month', 'Join Year','Age','BirthYear','Join_new', 'End Month', 'End Year', 'End_new','period','Join_new1','End_new1']
df1 = df.drop(drop_columns,axis=1)
df1.head()
# Out:
#         Club Affluence Gender Subscription Type  CustomerID  Status  \
# 0    Enfield      0.45      0                 0           1       0
# 1  Greenwich      0.96      1                 0           2       1
# 2  Islington      0.73      1                 0           3       0
# 3   Hounslow      0.45      1                 0           4       0
# 4     Barnet      0.25      0                 0           5       0
#
#   period group Age group
# 0    <=1months       20s
# 1       >1year       40s
# 2   6-12months       30s
# 3    1-3months       40s
# 4   6-12months       30s

# %% [markdown]
# ## Process Visit data

# %%
visitation_data_part1 = pd.read_csv('D:/IC/AIB/p1/visitationdataPART1.csv',parse_dates=['visitdate'])
visitation_data_part2 = pd.read_csv('D:/IC/AIB/p1/visitationdataPART2.csv', parse_dates=['visitdate'])

# %%
visitation_data = pd.concat((visitation_data_part1,visitation_data_part2))

# %%
visitation_data.head()
# Out:
#    CustomerID  visitdate TimeofVisit  peakvisits
# 0      126444 2009-05-01       05:45       False
# 1      456610 2009-05-01       05:45       False
# 2      293763 2009-05-01       06:00       False
# 3      151253 2009-05-01       06:15       False
# 4      476569 2009-05-01       06:15       False

# %%
#calculate the total visit by each customer
visit_count = visitation_data.groupby(by='CustomerID').count()['TimeofVisit']

# %%
visit_count.head()
# Out:
# CustomerID
# 1     20
# 2     74
# 3    165
# 4     52
# 5     93
# Name: TimeofVisit, dtype: int64

# %%
#Merge clients and visit data
df2 = df1.join(visit_count,on='CustomerID')
df2.head()
# Out:
#         Club Affluence Gender Subscription Type  CustomerID  Status  \
# 0    Enfield      0.45      0                 0           1       0
# 1  Greenwich      0.96      1                 0           2       1
# 2  Islington      0.73      1                 0           3       0
# 3   Hounslow      0.45      1                 0           4       0
# 4     Barnet      0.25      0                 0           5       0
#
#   period group Age group  TimeofVisit
# 0    <=1months       20s         20.0
# 1       >1year       40s         74.0
# 2   6-12months       30s        165.0
# 3    1-3months       40s         52.0
# 4   6-12months       30s         93.0

# %% [markdown]
# ## analyze churn rate from a variaty of customer demographics

# %%
churn_club = pd.DataFrame(columns = ["member", "nonmember", "churn rate"])
churn_club['member'] = df1.loc[df['Status']==1].groupby('Club').count()['Status']
churn_club['nonmember'] = df1.loc[df['Status']==0].groupby('Club').count()['Status']
churn_club['churn rate'] = churn_club['nonmember'] / (churn_club['nonmember']+churn_club['member'])

# %% [markdown]
# ## Houslow has the highest churn rate and redbridge has the lowest

# %%
churn_club['churn rate'].sort_values(ascending=False).plot.bar(figsize=(10,10))

# %% [markdown]
# ## We do not see a big difference among affluence groups

# %%
churn_aff = pd.DataFrame(columns = ["member", "nonmember", "churn rate"])
churn_aff['member'] = df1.loc[df['Status']==1].groupby('Affluence').count()['Status']
churn_aff['nonmember'] = df1.loc[df['Status']==0].groupby('Affluence').count()['Status']
churn_aff['churn rate'] = churn_aff['nonmember'] / (churn_aff['nonmember']+churn_aff['member'])
churn_aff['churn rate'].sort_values(ascending=False).plot.bar(figsize=(10,10))

# %% [markdown]
# ## Males are slightly more likely to churn than women

# %%
churn_gen = pd.DataFrame(columns = ["member", "nonmember", "churn rate"])
churn_gen['member'] = df1.loc[df['Status']==1].groupby('Gender').count()['Status']
churn_gen['nonmember'] = df1.loc[df['Status']==0].groupby('Gender').count()['Status']
churn_gen['churn rate'] = churn_gen['nonmember'] / (churn_gen['nonmember']+churn_gen['member'])
churn_gen['churn rate'].sort_values(ascending=False).plot.bar(figsize=(10,10))

# %% [markdown]
# ## Churn rate are decreasing with longer membership duration

# %%
churn_per = pd.DataFrame(columns = ["member", "nonmember", "churn rate"])
churn_per['member'] = df1.loc[df['Status']==1].groupby('period group').count()['Status']
churn_per['nonmember'] = df1.loc[df['Status']==0].groupby('period group').count()['Status']
churn_per['churn rate'] = churn_per['nonmember'] / (churn_per['nonmember']+churn_per['member'])
churn_per['churn rate'].sort_values(ascending=False).plot.bar(figsize=(10,10))

# %% [markdown]
# ## Older members are more likely to churn

# %%
churn_age = pd.DataFrame(columns = ["member", "nonmember", "churn rate"])
churn_age['member'] = df1.loc[df['Status']==1].groupby('Age group').count()['Status']
churn_age['nonmember'] = df1.loc[df['Status']==0].groupby('Age group').count()['Status']
churn_age['churn rate'] = churn_age['nonmember'] / (churn_age['nonmember']+churn_age['member'])
churn_age['churn rate'].sort_values(ascending=False).plot.bar(figsize=(10,10))

# %%
df1.head()
# Out:
#         Club Affluence Gender Subscription Type  CustomerID  Status  \
# 0    Enfield      0.45      0                 0           1       0
# 1  Greenwich      0.96      1                 0           2       1
# 2  Islington      0.73      1                 0           3       0
# 3   Hounslow      0.45      1                 0           4       0
# 4     Barnet      0.25      0                 0           5       0
#
#   period group Age group
# 0    <=1months       20s
# 1       >1year       40s
# 2   6-12months       30s
# 3    1-3months       40s
# 4   6-12months       30s

# %%
dic_club = {}
dic_per = {}
dic_age = {}

n = 0
for i in df1['Club'].unique():
    dic_club[i] = n
    n+=1
n=0
for i in df1['period group'].unique().sort_values():
    dic_per[i] = n
    n+=1
n=0
for i in df1['Age group'].unique().sort_values():
    dic_age[i] = n
    n+=1

# %%
dic_per
# Out:
# {'<=1months': 0, '1-3months': 1, '3-6months': 2, '6-12months': 3, '>1year': 4}

# %%
df1 = df1.replace({'Club':dic_club})
df1 = df1.replace({'period group':dic_per})
df1 = df1.replace({'Age group':dic_age})

df1.head()
# Out:
#    Club Affluence Gender Subscription Type  CustomerID  Status  period group  \
# 0     0      0.45      0                 0           1       0             0
# 1     1      0.96      1                 0           2       1             4
# 2     2      0.73      1                 0           3       0             3
# 3     3      0.45      1                 0           4       0             1
# 4     4      0.25      0                 0           5       0             3
#
#    Age group
# 0          1
# 1          3
# 2          2
# 3          3
# 4          2

# %%
from sklearn.model_selection import train_test_split

x_all = df1.drop(['Status','Club'], axis=1)
y_all = df1['Status']

x_tv, x_test, y_tv, y_test = train_test_split(x_all, y_all, random_state=0,test_size = 0.25)
x_valid, x_train, y_valid, y_train = train_test_split(x_tv, y_tv, random_state=1,test_size = 50/75)

print(x_train.shape, y_train.shape,x_valid.shape,y_valid.shape,x_test.shape,y_test.shape)
# Out:
# (425016, 6) (425016,) (212508, 6) (212508,) (212509, 6) (212509,)

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(x_train,y_train)

#Predict the response for training dataset
y_pred_train = clf.predict(x_train)

#Predict the response for validation dataset
y_pred_valid = clf.predict(x_valid)

print("Accuracy:",metrics.accuracy_score(y_train, y_pred_train))
print("Accuracy:",metrics.accuracy_score(y_valid, y_pred_valid))
# Out:
# Accuracy: 1.0
# Accuracy: 0.9156878799856947

# %% [markdown]
# ## Run decision tree and find the optimum depth

# %%
num_k = []
accuracy_train = []
accuracy_valid = []
for k in range(1, 30):
# Create Decision Tree classifer object
    clf = DecisionTreeClassifier(max_depth=k)
# Train Decision Tree Classifer
    clf = clf.fit(x_train,y_train)
#Predict the response for training dataset
    y_pred_train = clf.predict(x_train)
#Predict the response for validation dataset
    y_pred_valid = clf.predict(x_valid)
#record the maximum depth and accuracy
    num_k.append(k)
    accuracy_train.append(metrics.accuracy_score(y_train, y_pred_train))
    accuracy_valid.append(metrics.accuracy_score(y_valid, y_pred_valid))

plt.figure(figsize=(10, 10))
plt.plot(num_k, accuracy_train)
plt.plot(num_k, accuracy_valid)
plt.xlabel('k')
plt.ylabel('accuracy')
plt.show()

#print(num_k)
print(accuracy_train)
print(accuracy_valid)
# Out:
# [0.9384423174656954, 0.9384423174656954, 0.9393858113576901, 0.9401363713366085, 0.940738701601822, 0.9407716415382009, 0.9408281100005647, 0.9409386940726937, 0.9411763321851413, 0.9414633802021571, 0.9417692510399609, 0.9422562915278484, 0.9428374461196755, 0.9434985976998513, 0.9442373934157773, 0.9450138347732792, 0.9459338001392888, 0.9468890582942759, 0.9478937263538314, 0.9489313343497656, 0.9502183447211399, 0.9515100607977112, 0.9528017768742824, 0.9540981986560506, 0.9554793231313644, 0.9569639731210119, 0.9583521561541213, 0.9599168031321174, 0.9614108645321587]
# [0.9385105501910517, 0.9385105501910517, 0.9394752197564327, 0.940388126564647, 0.9409386940726937, 0.9409198712519058, 0.940868108494739, 0.9407645829804054, 0.9405951775933141, 0.940388126564647, 0.9402751896399194, 0.9401810755359798, 0.9398610875825851, 0.9396634479643119, 0.9392540516121746, 0.9390752348146894, 0.9386893669885369, 0.9382470307000207, 0.9376211719088222, 0.9372776554294426, 0.9367600278577748, 0.9360588777834247, 0.9355177216857719, 0.9352824364259228, 0.9343883524384964, 0.9339883674967531, 0.9334707399250852, 0.9326660643364014, 0.9319931484932332]

# %%
best_k = num_k[accuracy_valid.index(max(accuracy_valid))]
best_k
# Out:
# 5

# %%
from sklearn.metrics import confusion_matrix
clf = DecisionTreeClassifier(max_depth=5)
clf.fit(x_train, y_train)
confusion_matrix(y_valid, clf.predict(x_valid), labels=[1,0])
# Out:
# array([[  1568,  11499],
#        [  1052, 198389]], dtype=int64)

# %%
all_sample = clf.fit(x_all, y_all)

# %%
dic_age
# Out:
# {'<20': 0, '20s': 1, '30s': 2, '40s': 3, '>40s': 4}

# %%
from sklearn.externals.six import StringIO  
from sklearn.tree import export_graphviz
import pydotplus
from IPython.display import Image  
all_sample = clf.fit(x_all,y_all)
dot_data = StringIO()
export_graphviz(all_sample, out_file=dot_data, filled=True, rounded=True,
                special_characters=True, feature_names = list(x_all.columns) ,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('P1_tree.png')
Image(graph.create_png())
